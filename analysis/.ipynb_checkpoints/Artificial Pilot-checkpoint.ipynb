# %%
# %pylab inline
import json, csv, pandas, numpy, statsmodels, seaborn
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scikits.bootstrap as bootstrap 
from scipy import stats
from soph import boot,t_test_text_1samp,t_test_text_2samp,plot_by_one,plot_by_two


seaborn.set_style("whitegrid")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datafile = "../data/artificial-4-concepts/HITResultsFor3WUVMVA7OB8D4J99ULOW700SB28AZU.csv"

# %%
label_key = {                              #MTurk ruins labels so we have to recover them
    "Answer 1": "object level training",
    "Answer 2": "num_examples_to_show",
    "Answer 3": "num_examples_clicked",
    "Answer 4": "instruction_wait_time",
    "Answer 5": "feedback_wait_time",
    "Answer 6": "condition",
    "Answer 7": "pseudo_obj",
    "Answer 8": "border_values",
    "Answer 9": "pattern_values",
#     "Answer 7": "r_questions_pretest",
#     "Answer 8": "r_answers_pretest",
    "Answer 10": "training_complete",
    "Answer 11": "r_questions_posttest",
    "Answer 12": "r_answers_posttest",
    "Answer 13": "about",
    "Answer 14": "better",
    "Answer 15": "unclear",
    "Answer 16": "comment",
    "Answer 17": "external_aid",
    "Answer 18": "strategy",
    "Answer 19": "age",
    "Answer 20": "gender",
    "Answer 21": "exp_total_time",
    "WorkerId": "subids",
}
# here are the columns after this is finished ['AcceptTime', 'Annotation', 'AssignmentId', 'HitId', 'HitTitle',
#        'Status', 'SubmitTime', 'subids', 'about', 'age', 'better', 'block',
#        'comment', 'condition', 'correct', 'exp_total_time', 'external_aid',
#        'feedback_wait_time', 'gender', 'instruction_wait_time', 'level',
#        'num_examples_clicked', 'num_examples_to_show', 'phase', 'question',
#        'response', 'shape', 'strategy', 'training_complete',
#        'trial_num_within_block', 'trial_time', 'trial_type', 'unclear']
rel_key = {                               # answer key for relational questions of the form "are all x also y"
    "square_rectangle": True,
    "square_rhombus": True,
    "square_parallelogram": True,
    "rectangle_square": False,
    "rectangle_rhombus": False,
    "rectangle_parallelogram": True,
    "rhombus_square": False,
    "rhombus_rectangle": False,
    "rhombus_parallelogram": True,
    "parallelogram_square": False,
    "parallelogram_rhombus": False,
    "parallelogram_rectangle": False,
}
bool_key = {"Yes": True, "No": False}

# %%
with open(datafile, 'r') as f:
    csv_lines = list(csv.reader(f))
#     csv_lines = [ row for row in csv_lines]
# print(csv_lines[0])
# print(csv_lines[1])
labels = csv_lines.pop(0)

labels = [label_key[l] if l in label_key else l for l in labels]

subject_dicts = []

for row in csv_lines:
    
    new_row = []
    for item in row:
        try: 
            new_row.append(json.loads(item))
        except:
            new_row.append(item)
            
    subject_dicts.append(dict(zip(labels,new_row)))

# %%
keep_cols = ['subids','exp_total_time', 'condition']
    
tidy_dicts = []

for subj in subject_dicts:

    #grab object-level data
    obj_data = subj.pop("object level training")

    #grab relational-level data
#     pretest_answers = [bool_key[a] for a in subj.pop("r_answers_pretest")]
#     pretest_questions =  [q.replace("r_pretest_","") for q in subj.pop("r_questions_pretest")]
#     pretest_correct = [a == rel_key[q] for a,q in zip(pretest_answers,pretest_questions)]
#     pretest_dict = dict(zip(pretest_questions, pretest_correct))
    print(subj["r_answers_posttest"])
    posttest_answers = [bool_key[a] for a in subj.pop("r_answers_posttest")]
    posttest_questions =  [q.replace("r_posttest_","") for q in subj.pop("r_questions_posttest")]
    posttest_correct = [a == rel_key[q] for a,q in zip(posttest_answers,posttest_questions)]
    posttest_dict = dict(zip(posttest_questions, posttest_correct))
    
    subj = dict([(k,v) for k,v in subj.items() if k in keep_cols])
    
    # create a row for every object-level datapoint
    for obj in obj_data:
        new_row = subj.copy()
        new_row.update(obj)
        new_row["phase"] = "training"
        new_row["level"] = "object"
        tidy_dicts.append(new_row)
    

    # create a row for every relational question
    for q in posttest_dict:
        
        # pretest row
#         new_row = subj.copy()
#         new_row.update({
#             "phase": "pretest",
#             "level": "relational",
#             "question": q,
#             "correct": pretest_dict[q]
#         })
#         tidy_dicts.append(new_row)
        
        # posttest row
        new_row = subj.copy()
        new_row.update({
            "phase": "posttest",
            "level": "relational",
            "question": q,
            "correct": posttest_dict[q]
        })
        tidy_dicts.append(new_row)
        
tidy_df = pandas.DataFrame.from_dict(tidy_dicts)
# Out:
# ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No']
# label-order
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a036cdb499b7> in <module>()
#      14 #     pretest_dict = dict(zip(pretest_questions, pretest_correct))
#      15     print(subj["r_answers_posttest"])
# ---> 16     posttest_answers = [bool_key[a] for a in subj.pop("r_answers_posttest")]
#      17     posttest_questions =  [q.replace("r_posttest_","") for q in subj.pop("r_questions_posttest")]
#      18     posttest_correct = [a == rel_key[q] for a,q in zip(posttest_answers,posttest_questions)]
#
# <ipython-input-36-a036cdb499b7> in <listcomp>(.0)
#      14 #     pretest_dict = dict(zip(pretest_questions, pretest_correct))
#      15     print(subj["r_answers_posttest"])
# ---> 16     posttest_answers = [bool_key[a] for a in subj.pop("r_answers_posttest")]
#      17     posttest_questions =  [q.replace("r_posttest_","") for q in subj.pop("r_questions_posttest")]
#      18     posttest_correct = [a == rel_key[q] for a,q in zip(posttest_answers,posttest_questions)]
#
# KeyError: 'l'

# %%
subject_dicts[2]
# Out:
# {'AcceptTime': 'Mon Mar 20 10:19:27 PDT 2017',
#  'Annotation': ' ',
#  'AssignmentId': '3PJUZCGDJ7LN2OWBJSFLM5NQY7U98L',
#  'HitId': '3WUVMVA7OB8D4J99ULOW700SB28AZU',
#  'HitTitle': '$3 for 15 min. | Concept learning | University of Louisville',
#  'Status': 'Approved',
#  'SubmitTime': 'Mon Mar 20 10:49:34 PDT 2017',
#  'about': True,
#  'age': 413387,
#  'better': 3,
#  'border_values': 'Categorizing shapes as nonsense words like sime and dramand',
#  'comment': ['r_posttest_square_rectangle',
#   'r_posttest_rectangle_parallelogram',
#   'r_posttest_parallelogram_square',
#   'r_posttest_square_rhombus',
#   'r_posttest_rectangle_square',
#   'r_posttest_square_parallelogram',
#   'r_posttest_rectangle_rhombus',
#   'r_posttest_parallelogram_rhombus',
#   'r_posttest_parallelogram_rectangle',
#   'r_posttest_rhombus_square',
#   'r_posttest_rhombus_rectangle',
#   'r_posttest_rhombus_parallelogram'],
#  'condition': ['dash', 'solid'],
#  'exp_total_time': '29',
#  'external_aid': " I have never felt so stupid in my life (okay, hyperbole, but you get what I mean) sometimes I didn't even get 50% accuracy and I always felt like I was guessing. I did intend to get 2 blocks in a row correct, but this confused me a LOT and I swear I wasn't just answering randomly, I'm just terrible at it :(",
#  'feedback_wait_time': ['circle', 'square'],
#  'gender': ['No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'],
#  'instruction_wait_time': 'f',
#  'num_examples_clicked': 0,
#  'num_examples_to_show': [{'block': 1,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 1201,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 2,
#    'trial_time': 1611,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 3,
#    'trial_time': 737,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 4,
#    'trial_time': 714,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 5,
#    'trial_time': 827,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 6,
#    'trial_time': 523,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 7,
#    'trial_time': 570,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 8,
#    'trial_time': 938,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 9,
#    'trial_time': 803,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 10,
#    'trial_time': 698,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 11,
#    'trial_time': 1154,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 12,
#    'trial_time': 1051,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 555,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 14,
#    'trial_time': 681,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 15,
#    'trial_time': 2010,
#    'trial_type': 'training'},
#   {'block': 1,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 16,
#    'trial_time': 803,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 1,
#    'trial_time': 524,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 2,
#    'trial_time': 977,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 3,
#    'trial_time': 833,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 4,
#    'trial_time': 1099,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 5,
#    'trial_time': 1107,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 6,
#    'trial_time': 1196,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 7,
#    'trial_time': 1291,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 8,
#    'trial_time': 754,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 9,
#    'trial_time': 803,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 650,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 11,
#    'trial_time': 714,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 12,
#    'trial_time': 900,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 1394,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 14,
#    'trial_time': 611,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 15,
#    'trial_time': 1243,
#    'trial_type': 'training'},
#   {'block': 2,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 16,
#    'trial_time': 827,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 902,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 2,
#    'trial_time': 842,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 3,
#    'trial_time': 1139,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 4,
#    'trial_time': 1147,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 5,
#    'trial_time': 2178,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 6,
#    'trial_time': 723,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 7,
#    'trial_time': 555,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 8,
#    'trial_time': 787,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 9,
#    'trial_time': 730,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 434,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 11,
#    'trial_time': 955,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 12,
#    'trial_time': 522,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 635,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 14,
#    'trial_time': 706,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 15,
#    'trial_time': 834,
#    'trial_type': 'training'},
#   {'block': 3,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 16,
#    'trial_time': 1841,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 641,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 2,
#    'trial_time': 827,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 3,
#    'trial_time': 756,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 4,
#    'trial_time': 922,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 5,
#    'trial_time': 802,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 6,
#    'trial_time': 475,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 7,
#    'trial_time': 928,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 8,
#    'trial_time': 900,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 9,
#    'trial_time': 851,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 601,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 11,
#    'trial_time': 939,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 12,
#    'trial_time': 1098,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 13,
#    'trial_time': 618,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 14,
#    'trial_time': 523,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 15,
#    'trial_time': 595,
#    'trial_type': 'training'},
#   {'block': 4,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 16,
#    'trial_time': 1075,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 1,
#    'trial_time': 1009,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 2,
#    'trial_time': 738,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 3,
#    'trial_time': 610,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 4,
#    'trial_time': 883,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 5,
#    'trial_time': 1121,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 6,
#    'trial_time': 779,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 7,
#    'trial_time': 1498,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 8,
#    'trial_time': 780,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 9,
#    'trial_time': 819,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 10,
#    'trial_time': 1058,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 11,
#    'trial_time': 803,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 12,
#    'trial_time': 1538,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 13,
#    'trial_time': 568,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 14,
#    'trial_time': 531,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 15,
#    'trial_time': 418,
#    'trial_type': 'training'},
#   {'block': 5,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 16,
#    'trial_time': 402,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 1,
#    'trial_time': 431,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 2,
#    'trial_time': 563,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 3,
#    'trial_time': 762,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 4,
#    'trial_time': 276,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 5,
#    'trial_time': 401,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 6,
#    'trial_time': 1298,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 7,
#    'trial_time': 490,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 8,
#    'trial_time': 1138,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 9,
#    'trial_time': 723,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 707,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 11,
#    'trial_time': 787,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 12,
#    'trial_time': 2554,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 13,
#    'trial_time': 777,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 14,
#    'trial_time': 1075,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 15,
#    'trial_time': 746,
#    'trial_type': 'training'},
#   {'block': 6,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 16,
#    'trial_time': 875,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 1601,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 2,
#    'trial_time': 739,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 3,
#    'trial_time': 962,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 4,
#    'trial_time': 1347,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 5,
#    'trial_time': 771,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 6,
#    'trial_time': 826,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 7,
#    'trial_time': 891,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 8,
#    'trial_time': 810,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 9,
#    'trial_time': 812,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 10,
#    'trial_time': 723,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 11,
#    'trial_time': 235,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 12,
#    'trial_time': 274,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 625,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 14,
#    'trial_time': 601,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 15,
#    'trial_time': 467,
#    'trial_type': 'training'},
#   {'block': 7,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 16,
#    'trial_time': 578,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 558,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 2,
#    'trial_time': 1059,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 3,
#    'trial_time': 1579,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 4,
#    'trial_time': 770,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 5,
#    'trial_time': 683,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 6,
#    'trial_time': 643,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 7,
#    'trial_time': 275,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 8,
#    'trial_time': 227,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 9,
#    'trial_time': 138,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 330,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 11,
#    'trial_time': 475,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 12,
#    'trial_time': 378,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 146,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 14,
#    'trial_time': 371,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 15,
#    'trial_time': 179,
#    'trial_type': 'training'},
#   {'block': 8,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 16,
#    'trial_time': 50,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 1,
#    'trial_time': 471,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 2,
#    'trial_time': 267,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 3,
#    'trial_time': 146,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 4,
#    'trial_time': 403,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 5,
#    'trial_time': 432,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 6,
#    'trial_time': 163,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 7,
#    'trial_time': 459,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 8,
#    'trial_time': 307,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 9,
#    'trial_time': 481,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 10,
#    'trial_time': 627,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 11,
#    'trial_time': 370,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 12,
#    'trial_time': 579,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 13,
#    'trial_time': 91,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 14,
#    'trial_time': 337,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 15,
#    'trial_time': 83,
#    'trial_type': 'training'},
#   {'block': 9,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 16,
#    'trial_time': 106,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 369,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 2,
#    'trial_time': 564,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 3,
#    'trial_time': 1290,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 4,
#    'trial_time': 1074,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 5,
#    'trial_time': 715,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 6,
#    'trial_time': 835,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 7,
#    'trial_time': 1156,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 8,
#    'trial_time': 643,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 9,
#    'trial_time': 1187,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 10,
#    'trial_time': 1107,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 11,
#    'trial_time': 267,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': True,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 12,
#    'trial_time': 162,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 13,
#    'trial_time': 379,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 14,
#    'trial_time': 996,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 15,
#    'trial_time': 594,
#    'trial_type': 'training'},
#   {'block': 10,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 16,
#    'trial_time': 362,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 1,
#    'trial_time': 578,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 2,
#    'trial_time': 194,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 3,
#    'trial_time': 266,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 4,
#    'trial_time': 145,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 5,
#    'trial_time': 284,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 6,
#    'trial_time': 290,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 7,
#    'trial_time': 179,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 8,
#    'trial_time': 179,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 9,
#    'trial_time': 123,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 10,
#    'trial_time': 714,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 11,
#    'trial_time': 121,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 12,
#    'trial_time': 170,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 139,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 14,
#    'trial_time': 154,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 15,
#    'trial_time': 155,
#    'trial_type': 'training'},
#   {'block': 11,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 16,
#    'trial_time': 202,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 293,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 2,
#    'trial_time': 258,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 3,
#    'trial_time': 131,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 4,
#    'trial_time': 116,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 5,
#    'trial_time': 267,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 6,
#    'trial_time': 204,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 7,
#    'trial_time': 139,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 8,
#    'trial_time': 322,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 9,
#    'trial_time': 91,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 291,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 11,
#    'trial_time': 154,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 12,
#    'trial_time': 155,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 13,
#    'trial_time': 131,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 14,
#    'trial_time': 130,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 15,
#    'trial_time': 122,
#    'trial_type': 'training'},
#   {'block': 12,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 16,
#    'trial_time': 219,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 1,
#    'trial_time': 1028,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 2,
#    'trial_time': 698,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 3,
#    'trial_time': 1450,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 4,
#    'trial_time': 690,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 5,
#    'trial_time': 1099,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': False,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 6,
#    'trial_time': 1482,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 7,
#    'trial_time': 658,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 8,
#    'trial_time': 818,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 9,
#    'trial_time': 947,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 859,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 11,
#    'trial_time': 1027,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 12,
#    'trial_time': 754,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 13,
#    'trial_time': 682,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 14,
#    'trial_time': 698,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 15,
#    'trial_time': 882,
#    'trial_type': 'training'},
#   {'block': 13,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 16,
#    'trial_time': 793,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 1,
#    'trial_time': 763,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 2,
#    'trial_time': 866,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 3,
#    'trial_time': 970,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 4,
#    'trial_time': 675,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 5,
#    'trial_time': 609,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 6,
#    'trial_time': 987,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'square',
#    'trial_num_within_block': 7,
#    'trial_time': 770,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 8,
#    'trial_time': 634,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 9,
#    'trial_time': 899,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 10,
#    'trial_time': 987,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 11,
#    'trial_time': 890,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 12,
#    'trial_time': 634,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'square',
#    'response': 'No',
#    'shape': 'rectangle',
#    'trial_num_within_block': 13,
#    'trial_time': 1002,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 14,
#    'trial_time': 699,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 15,
#    'trial_time': 1026,
#    'trial_type': 'training'},
#   {'block': 14,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 16,
#    'trial_time': 809,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 1,
#    'trial_time': 1144,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 2,
#    'trial_time': 955,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 3,
#    'trial_time': 603,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 4,
#    'trial_time': 858,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 5,
#    'trial_time': 747,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'parallelogram',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 6,
#    'trial_time': 738,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 7,
#    'trial_time': 908,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 8,
#    'trial_time': 778,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'parallelogram',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 9,
#    'trial_time': 931,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'rhombus',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 10,
#    'trial_time': 1010,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'parallelogram',
#    'trial_num_within_block': 11,
#    'trial_time': 708,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 12,
#    'trial_time': 554,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': False,
#    'question': 'square',
#    'response': 'Yes',
#    'shape': 'rhombus',
#    'trial_num_within_block': 13,
#    'trial_time': 498,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'No',
#    'shape': 'rhombus',
#    'trial_num_within_block': 14,
#    'trial_time': 169,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'square',
#    'trial_num_within_block': 15,
#    'trial_time': 530,
#    'trial_type': 'training'},
#   {'block': 15,
#    'correct': True,
#    'question': 'rectangle',
#    'response': 'Yes',
#    'shape': 'rectangle',
#    'trial_num_within_block': 16,
#    'trial_time': 514,
#    'trial_type': 'training'}],
#  'object level training': 'No',
#  'pattern_values': {'parallelogram': ['sime', 'simes'],
#   'rectangle': ['julex', 'julexes'],
#   'rhombus': ['dramand', 'dramands'],
#   'square': ['shird', 'shirds']},
#  'pseudo_obj': '',
#  'r_answers_posttest': 'random-order',
#  'r_questions_posttest': '',
#  'strategy': 'No',
#  'subids': 'A36SM7QM8OK3H6',
#  'training_complete': 500,
#  'unclear': 3}

# %%
block_to_section = lambda x: x if x in ["pretest", "posttest"] else "training"
tidy_df["section"] = tidy_df.block.map(block_to_section)
# baseline_data["question_text"] = ["Are all {}s also {}s?".format(r.question,r["shape"]) 
#                                   for i,r in baseline_data.iterrows()]

tidy_df["block_reached_crit"] = 15
tidy_df["blocks_to_go"] = 0
tidy_df["reached_crit"] = False
tidy_df["incorrect"] = [int(~i) for i in tidy_df.correct]
for subj in tidy_df.subids.unique():
    subj_i = (tidy_df.subids == subj)&(tidy_df.section=='training')
    subj_blocks = tidy_df.block[subj_i]
#     print(max(subj_blocks))
    tidy_df.block_reached_crit[tidy_df.subids == subj] = max(subj_blocks)
    tidy_df.blocks_to_go[subj_i] = max(subj_blocks) - subj_blocks +1
    tidy_df.reached_crit[tidy_df.subids == subj] = max(subj_blocks) != 15
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6fc05d6c833f> in <module>()
#       1 block_to_section = lambda x: x if x in ["pretest", "posttest"] else "training"
# ----> 2 tidy_df["section"] = tidy_df.block.map(block_to_section)
#       3 # baseline_data["question_text"] = ["Are all {}s also {}s?".format(r.question,r["shape"])
#       4 #                                   for i,r in baseline_data.iterrows()]
#       5
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'block'
